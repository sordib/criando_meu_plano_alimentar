# %% [markdown]
# <a href="https://colab.research.google.com/github/sordib/criando_meu_plano_alimentar/blob/main/Plano_Alimentar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Definindo a dieta

pre_treino = {
    "Pães": ["Batata Doce, Inhame ou Mandioca (pequena cozida)", "Goma de Tapioca + Chia", "Avelã, Quinoa ou Amaranto (em flocos)",
             "Cuscuz + Chia", "Biscoitos de Arroz Integral", "Pão Sírio Integral Médio"],
    "Oléos:": ["Manteiga sem Sal (pincelar)", "Óleo de Coco, Girassol ou Azeite Extravirgem"],
    "Frutas": ["Abacate", "Cacho Pequeno de Uvas", "Meio Mamão Papaia ou Manga", "Fruta Média (banana, caqui, fruta do conde, goiaba, maçã, mexerica, laranja, pêra)",
               "Ameixas Frescas, Pêssego, Kiwi ou Nespera", "10 Morangos", "Fatia de Melancia, Dia Melão ou Mamão Formosa", "2 Fatias de Abacaxi", "25g de Coco Seco ou Fresco",
               "250ml de Suco (natural, polpa, integral) ou Água de Coco"],
}

cafe_da_manha = {
    "Pães": ["Batata Doce, Inhame ou Mandioca (pequena cozida)", "Goma de Tapioca + Chia", "Avelã, Quinoa ou Amaranto (em flocos)",
             "Cuscuz + Chia", "Biscoitos de Arroz Integral", "Pão Sírio Integral Médio"],
    "Oléos:": ["Manteiga sem Sal (pincelar)", "Óleo de Coco, Girassol ou Azeite Extravirgem"],
    "Laticínios1": ["Leite Semidesnatado ou Vegetal", "Iogurte Light/Zero Gordura", "Bebida Láctea ou Fermentada Carboidrato",
                    "Requeijão Light ou Creme de Rico", "Queijo Cottage", "Ricota Temperada ou Queijo Minas Frescal ou Meia Cura (2 fatias médias)"],
    "Laticínios2": ["Leite Semidesnatado ou Vegetal", "Iogurte Light/Zero Gordura", "Bebida Láctea ou Fermentada Carboidrato",
                    "Requeijão Light ou Creme de Rico", "Queijo Cottage", "Ricota Temperada ou Queijo Minas Frescal ou Meia Cura (2 fatias médias)"],
}

almoco = {
      "Arroz": ["3 Colheres (sopa) de Arroz (integral, parboilizado ou branco)", "1 Escumadeira de Macarrão Integral, Arroz ou Milho",
              "1 Unidade (média cozida) de Batata, Inhame, Mandioca, Batata Doce, Cará ou Mandioquinha", "1 Espiga (g) de Milho"],

    "Leguminosas": ["1 Concha (média) de Feijão (carioca, preto, branco), Ervilha, Lentilha, Grão de Bico ou Soja"],

    "Carnes": ["4 Cubos (pequenos) de Carne", "4 Coxas (pequenas) de Frango", "4 Colheres (sopa) de Carne Moída ou Frango Desfiado",
               "1 Bife ou Filé (frango ou peixe) - 100g", "2 Ovos"],

    "Hortaliças": ["Legumes (3 colheres de sopa)", "Verduras (Meio Prato Fundo)"],

    "Hortaliças2": ["Legumes (3 colheres de sopa)", "Verduras (Meio Prato Fundo)"],

    "Frutas": ["Abacate", "Cacho Pequeno de Uvas", "Meio Mamão Papaia ou Manga", "Fruta Média (banana, caqui, fruta do conde, goiaba, maçã, mexerica, laranja, pêra)",
               "Ameixas Frescas, Pêssego, Kiwi ou Nespera", "10 Morangos", "Fatia de Melancia, Dia Melão ou Mamão Formosa", "2 Fatias de Abacaxi", "25g de Coco Seco ou Fresco",
               "250ml de Suco (natural, polpa, integral) ou Água de Coco"],

    "Açúcares (opcional)": ["1 Bombom", "20g de Chocolate Meio Amargo", "1 Fatia Pequena de Manjar","1 Picolé de Frutas",
                 "1 Colher (sopa) de Doce Caseiro", "Taça (pequena) de Gelatina Caseira",
                 "2 Colheres (sopa) de Achocolatado, Açúcar ou Mel", "3 Balas de Iogurte, Hortelã ou Caramelo",
                 "2 Colheres (servir) de Mousse de Frutas"],
}

lanche_tarde = {
        "Pães": ["Batata Doce, Inhame ou Mandioca (pequena cozida)", "Goma de Tapioca + Chia", "Avelã, Quinoa ou Amaranto (em flocos)",
             "Cuscuz + Chia", "Biscoitos de Arroz Integral", "Pão Sírio Integral Médio"],
        "Oléos:": ["Manteiga sem Sal (pincelar)", "Óleo de Coco, Girassol ou Azeite Extravirgem"],
        "Oleaginosas": ["1 Colher (sopa) de Semente de Chia, Linhaça, Abóbora ou Gergelim", "2 Castanhas do Pará ou Nozes",
                   "6 Amêndoas ou Avelãs", "2 Colheres (sopa) de Pasta Integral de Amendoim" ],
        "Carnes": ["4 Cubos (pequenos) de Carne", "4 Coxas (pequenas) de Frango", "4 Colheres (sopa) de Carne Moída ou Frango Desfiado",
               "1 Bife ou Filé (frango ou peixe) - 100g", "2 Ovos" ],
        "Laticínios": ["Leite Semidesnatado ou Vegetal", "Iogurte Light/Zero Gordura", "Bebida Láctea ou Fermentada Carboidrato",
                   "Requeijão Light ou Creme de Rico", "Queijo Cottage", "Ricota Temperada ou Queijo Minas Frescal ou Meia Cura (2 fatias médias)"],
}

jantar = {
        "Frutas": ["Abacate", "Cacho Pequeno de Uvas", "Meio Mamão Papaia ou Manga", "Fruta Média (banana, caqui, fruta do conde, goiaba, maçã, mexerica, laranja, pêra)",
               "Ameixas Frescas, Pêssego, Kiwi ou Nespera", "10 Morangos", "Fatia de Melancia, Dia Melão ou Mamão Formosa", "2 Fatias de Abacaxi", "25g de Coco Seco ou Fresco",
               "250ml de Suco (natural, polpa, integral) ou Água de Coco"],
        "Pães": ["Batata Doce, Inhame ou Mandioca (pequena cozida)", "Goma de Tapioca + Chia", "Avelã, Quinoa ou Amaranto (em flocos)",
             "Cuscuz + Chia", "Biscoitos de Arroz Integral", "Pão Sírio Integral Médio"],
        "Oléos:": ["Manteiga sem Sal (pincelar)", "Óleo de Coco, Girassol ou Azeite Extravirgem"],
        "Laticínios": ["Leite Semidesnatado ou Vegetal", "Iogurte Light/Zero Gordura", "Bebida Láctea ou Fermentada Carboidrato",
                   "Requeijão Light ou Creme de Rico", "Queijo Cottage", "Ricota Temperada ou Queijo Minas Frescal ou Meia Cura (2 fatias médias)"],
}

def gerar_sugestao_alimentar(opcoes):
    sugestao = {}
    for categoria, alimentos in opcoes.items():
        escolha = random.choice(alimentos)
        sugestao[categoria] = escolha
    return sugestao

# Gerar sugestão alimentar com base nas opções disponíveis em casa
sugestao_pre_treino = gerar_sugestao_alimentar(pre_treino)
sugestao_cafe_da_manha = gerar_sugestao_alimentar(cafe_da_manha)
sugestao_almoco = gerar_sugestao_alimentar(almoco)
sugestao_lanche = gerar_sugestao_alimentar(lanche_tarde)
sugestao_jantar = gerar_sugestao_alimentar(jantar)

# %%
# Mapeamento de números para refeições
refeicoes_legenda = {
    "1": "Pré-Treino",
    "2": "Café da Manhã",
    "3": "Almoço",
    "4": "Lanche da Tarde",
    "5": "Jantar",
}

# Loop principal
while True:
    # Perguntar ao usuário qual refeição deseja e exibir a sugestão correspondente
    refeicao_escolhida = input("Qual refeição você gostaria de receber sugestões? Digite o número(pré-treino - 1, café da manhã - 2, almoço - 3, lanche - 4 ou jantar - 5), ou 'sair' para encerrar: ").lower()

    if refeicao_escolhida == "sair":
        print("Encerrando o programa.")
        break

    if refeicao_escolhida not in refeicoes_legenda:
        print("Refeição inválida. Por favor, escolha entre 1, 2, 3, 4 ou 5.")
        continue

    sugestao = None
    if refeicao_escolhida == "1":
        sugestao = gerar_sugestao_alimentar(pre_treino)
    elif refeicao_escolhida == "2":
        sugestao = gerar_sugestao_alimentar(cafe_da_manha)
    elif refeicao_escolhida == "3":
        sugestao = gerar_sugestao_alimentar(almoco)
    elif refeicao_escolhida == "4":
        sugestao = gerar_sugestao_alimentar(lanche_tarde)
    elif refeicao_escolhida == "5":
        sugestao = gerar_sugestao_alimentar(jantar)

    if sugestao:
        print("\nSugestão para", refeicoes_legenda[refeicao_escolhida] + ":")
        for categoria, escolha in sugestao.items():
            print(f"{categoria}: {escolha}")

    nova_sugestao = input("Deseja receber sugestões para outra refeição? (Digite 'sim' para continuar ou 'sair' para encerrar): ").lower()
    if nova_sugestao != "sim":
        print("Encerrando o programa.")
        break

# %%
# Mapeamento de números para refeições
refeicoes_legenda = {
    "1": "Pré-Treino",
    "2": "Café da Manhã",
    "3": "Almoço",
    "4": "Lanche da Tarde",
    "5": "Jantar",
}

# Loop principal
while True:
    # Perguntar ao usuário qual refeição deseja e exibir a sugestão correspondente
    refeicao_escolhida = input("Qual refeição você gostaria de receber sugestões? Digite o número(pré-treino - 1, café da manhã - 2, almoço - 3, lanche - 4 ou jantar - 5), ou 'sair' para encerrar: ").lower()

    if refeicao_escolhida == "sair":
        print("Encerrando o programa.")
        break

    if refeicao_escolhida not in refeicoes_legenda:
        print("Refeição inválida. Por favor, escolha entre 1, 2, 3, 4 ou 5.")
        continue

    sugestao = None
    match refeicao_escolhida:
      case "1":
          sugestao = gerar_sugestao_alimentar(pre_treino)
      case "2":
          sugestao = gerar_sugestao_alimentar(cafe_da_manha)
      case "3":
          sugestao = gerar_sugestao_alimentar(almoco)
      case "4":
          sugestao = gerar_sugestao_alimentar(lanche_tarde)
      case "5":
          sugestao = gerar_sugestao_alimentar(jantar)

    if sugestao:
        print("\nSugestão para", refeicoes_legenda[refeicao_escolhida] + ":")
        for categoria, escolha in sugestao.items():
            print(f"{categoria}: {escolha}")

    nova_sugestao = input("Deseja receber sugestões para outra refeição? (Digite 'sim' para continuar ou 'sair' para encerrar): ").lower()
    if nova_sugestao != "sim":
        print("Encerrando o programa.")
        break
